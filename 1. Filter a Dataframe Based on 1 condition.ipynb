# %%
import pandas as pd

# %%
df_cpcb_dataset = pd.read_csv('concrete.csv')

# %%
df_cpcb_dataset.head(3)
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22

# %% [markdown]
# # 1 Filter dataframe based on a condition

# %%
# find which rows have "200" in the "Cement" column
df_cpcb_dataset['cement']==250
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1025    False
# 1026    False
# 1027    False
# 1028    False
# 1029    False
# Name: cement, Length: 1030, dtype: bool

# %%
df_cpcb_dataset['cement']!=250
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1025     True
# 1026     True
# 1027     True
# 1028     True
# 1029     True
# Name: cement, Length: 1030, dtype: bool

# %%
# filter dataframe based on condition
df_cpcb_dataset[df_cpcb_dataset['cement']==250]
# Out:
#       cement   slag   ash  water  superplastic  coarseagg  fineagg  age  \
# 2      250.0    0.0  95.7  187.4           5.5      956.9    861.2   28
# 59     250.0    0.0  95.7  187.4           5.5      956.9    861.2  100
# 121    250.0    0.0  95.7  191.8           5.3      948.9    857.2   56
# 358    250.0    0.0  95.7  187.4           5.5      956.9    861.2   14
# 422    250.0    0.0  95.7  187.4           5.5      956.9    861.2    3
# 618    250.0    0.0  95.7  187.4           5.5      956.9    861.2   56
# 650    250.0    0.0  95.7  191.8           5.3      948.9    857.2    3
# 659    250.0    0.0   0.0  182.0           0.0     1100.0    820.0    7
# 812    250.0    0.0  95.7  191.8           5.3      948.9    857.2   14
# 818    250.0    0.0   0.0  182.0           0.0     1100.0    820.0   28
# 824    250.0  180.0  95.0  159.0           9.5      860.0    800.0   28
# 893    250.0    0.0  95.7  191.8           5.3      948.9    857.2  100
# ...

# %%
# verify which companies are in the "Company" olumn with value_counts()
df_cpcb_dataset[df_cpcb_dataset['cement']==250].value_counts('cement')
# Out:
# cement
# 250.0    13
# Name: count, dtype: int64

# %% [markdown]
# # 1.1 Excercise 1

# %%
# find which rows don't have "250" in the "cement" column
df_cpcb_dataset['cement']!=250
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1025     True
# 1026     True
# 1027     True
# 1028     True
# 1029     True
# Name: cement, Length: 1030, dtype: bool

# %%
# filter dataframe based on a dataframe
df_cpcb_dataset[df_cpcb_dataset['cement']!=250]
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# 5      255.0    0.0    0.0  192.0           0.0      889.8    945.0   90
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 3        45.85
# 4        18.29
# ...

# %% [markdown]
# # 1.2 Excercise 2

# %%
# find cement with price over 400
df_cpcb_dataset['cement']>400
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1025    False
# 1026     True
# 1027    False
# 1028    False
# 1029     True
# Name: cement, Length: 1030, dtype: bool
