# %%
import pandas as pd

# %%
df_cpcb_dataset = pd.read_csv('concrete.csv')

# %%
df_cpcb_dataset.head(4)
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85

# %% [markdown]
# # 1. unique()
# Return unique values of series object. (Uniques are returned in order of appearance)

# %%
# get unique elements  in the "cement" column
df_cpcb_dataset['cement'].unique()
# Out:
# array([141.3, 168.9, 250. , 266. , 154.8, 255. , 166.8, 251.4, 296. ,
#        155. , 151.8, 173. , 385. , 237.5, 167. , 213.8, 336. , 190.7,
#        312.7, 229.7, 228. , 236. , 132. , 331. , 310. , 304. , 425. ,
#        166.1, 339. , 475. , 145.7, 313. , 178. , 165. , 277.2, 325. ,
#        194.7, 246.8, 382. , 149. , 531.3, 387. , 193.5, 326. , 337.9,
#        200. , 218.9, 234. , 309.9, 350. , 182. , 480. , 295.7, 233.8,
#        379.5, 332.5, 237. , 238.1, 323.7, 342. , 388.6, 147.8, 290.4,
#        500. , 284. , 218.2, 190.3, 116. , 277. , 376. , 273. , 212.5,
#        362.6, 275.1, 139.6, 427.5, 183.9, 318.8, 252. , 149.5, 540. ,
#        380. , 436. , 281. , 151.6, 326.5, 397. , 238. , 158.6, 302. ,
#        192. , 155.6, 160. , 222.4, 251.8, 213.5, 446. , 133. , 122.6,
#        290.2, 375. , 181.4, 298.2, 162. , 262. , 213.7, 313.3, 322. ,
#        173.5, 299.8, 198.6, 286.3, 349. , 520. , 252.1, 255.5, 172.4,
# ...

# %%
# get unique elements in the "slag" column
df_cpcb_dataset['slag'].unique()
# Out:
# array([212. ,  42.2,   0. , 114. , 183.4, 250.2, 184. , 178.1, 116. ,
#        237.5, 187. ,  98.1, 342.1, 157. , 207. , 143. ,  76. , 106.3,
#         99. , 172.6, 145. , 129.8,  97.8,  75.4, 118. ,  20. , 290.2,
#        189. , 200. , 156. , 142.8,  45.2, 151.2, 142.5,  92. , 282.8,
#        133. ,  38. ,  97.1, 175.1,  15. , 128.5,  54.6, 173. , 209.4,
#         47.5, 122.6, 212.5,  97. , 236. ,  17.2, 148.9, 288. , 243.5,
#        128. , 183. ,  24. , 210. , 183.9, 193.5,  93.8, 214. , 111. ,
#        262.2,  95. , 188. ,  50.1, 132.4, 200.9, 170.3,  13.6, 149. ,
#         19. , 189.2, 153. ,  11. , 137. , 209. , 250. , 161.6, 190. ,
#         86. ,  22. , 243. , 196. , 135.7, 147.2, 129.9, 170. , 162.4,
#         53.8, 117.2, 166.8, 177. , 148.6, 239. , 118.8, 100.6,  91.7,
#        166. , 230.5, 190.1, 260. , 116.8, 169. , 305.3, 272.8,  50. ,
#        158.8, 124.1,  26. , 238.7, 140. , 170.2, 134. ,  93.4, 120. ,
# ...

# %%
# get the length of unique elements
len(df_cpcb_dataset['slag'].unique())
len(df_cpcb_dataset['cement'].unique())
# Out:
# 278

# %%
len(df_cpcb_dataset['slag'].unique())
# Out:
# 185

# %% [markdown]
# # 1. nunique()
# Return number of unique elements in the object(Excludes NA vlues by default)

# %%
# get number of unique elements in the "Company" column
df_cpcb_dataset['cement'].nunique()
# Out:
# 278

# %%
# get number of unique elements in the "inhes" column
df_cpcb_dataset['slag'].nunique()
# Out:
# 185
