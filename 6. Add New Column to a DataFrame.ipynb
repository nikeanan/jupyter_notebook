# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('rainfall_by_districts_2019.csv')
df_exams.head()
# Out:
#   S.No      District  \
# 0    1       Chennai
# 1    2  Kancheepuram
# 2    3    Tiruvallur
# 3    4     Cuddalore
# 4    5    Villupuram
#
#    Actual Rainfall in South West Monsoon (June'17 to September'17) in mm  \
# 0                                              449.7
# 1                                              488.5
# 2                                              498.7
# 3                                              465.7
# 4                                              441.3
#
#    Normal Rainfall in South West Monsoon (June'17 to September'17) in mm  \
# 0                                              439.1
# 1                                              490.8
# 2                                              451.6
# 3                                              383.1
# 4                                              408.3
#
#    Actual Rainfall in North East Monsoon (October'17 to December'17) in mm  \
# 0                                              937.8
# ...

# %% [markdown]
# # 1 Adding a new column
# # 1.1 Adding a new column with a scalar value

# %%
# adding new colummn to a dataframe
df_exams["Normal Rainfall in Winter Season (January'18 to and February'18) in mm"] = 33
df_exams
# Out:
#        S.No         District  \
# 0         1          Chennai
# 1         2     Kancheepuram
# 2         3       Tiruvallur
# 3         4        Cuddalore
# 4         5       Villupuram
# 5         6          Vellore
# 6         7   Tiruvannamalai
# 7         8            Salem
# 8         9         Namakkal
# 9        10       Dharmapuri
# 10       11      Krishnagiri
# 11       12         Tiruppur
# 12       13       Coimbatore
# 13       14            Erode
# 14       15  Tiruchirappalli
# 15       16            Karur
# 16       17       Perambalur
# 17       18      Pudukkottai
# 18       19        Thanjavur
# 19       20        Tiruvarur
# 20       21     Nagapattinam
# 21       22          Madurai
# 22       23            Theni
# 23       24         Dindigul
# 24       25   Ramanathapuram
# 25       26     Virudhunagar
# 26       27        Sivaganga
# 27       28      Tirunelveli
# 28       29      Thoothukudi
# 29       30     The Nilgiris
# 30       31         Ariyalur
# ...

# %% [markdown]
# # 1.2 Adding a new column with an array
# The dataframe has 32 rows so we need to create an array with 32 elememts

# %%
# import numpy
import numpy as np

# %%
# create an array of 33 elements
rainfall_data = np.arange(0,33)

# %%
# length of the array
len(np.arange(0,33))
# Out:
# 33

# %%
# adding a new column to dataframe with an array
df_exams['rainfall_data'] = rainfall_data
df_exams
# Out:
#        S.No         District  \
# 0         1          Chennai
# 1         2     Kancheepuram
# 2         3       Tiruvallur
# 3         4        Cuddalore
# 4         5       Villupuram
# 5         6          Vellore
# 6         7   Tiruvannamalai
# 7         8            Salem
# 8         9         Namakkal
# 9        10       Dharmapuri
# 10       11      Krishnagiri
# 11       12         Tiruppur
# 12       13       Coimbatore
# 13       14            Erode
# 14       15  Tiruchirappalli
# 15       16            Karur
# 16       17       Perambalur
# 17       18      Pudukkottai
# 18       19        Thanjavur
# 19       20        Tiruvarur
# 20       21     Nagapattinam
# 21       22          Madurai
# 22       23            Theni
# 23       24         Dindigul
# 24       25   Ramanathapuram
# 25       26     Virudhunagar
# 26       27        Sivaganga
# 27       28      Tirunelveli
# 28       29      Thoothukudi
# 29       30     The Nilgiris
# 30       31         Ariyalur
# ...

# %%
# create random integer numbers between 1 and 33
np.random.randint(1,100, size = 33)
# Out:
# array([12, 73, 17, 29, 38, 44,  2, 32, 81, 73, 97, 99, 57, 98, 63, 84, 58,
#        11,  4, 62, 87, 37, 36, 17, 32, 37, 70,  2, 57, 90, 43, 54, 11],
#       dtype=int32)

# %%
len(np.random.randint(1,100, size = 33))
# Out:
# 33

# %%
int_rainfall_data = np.random.randint(1,100, size = 33)

# %%
# min value inclusive and high value exclusive
min(int_rainfall_data)
max(int_rainfall_data)
# Out:
# np.int32(97)

# %%
# adding a new column to dataframe withan array
df_exams['rainfall_data'] = int_rainfall_data
df_exams
# Out:
#        S.No         District  \
# 0         1          Chennai
# 1         2     Kancheepuram
# 2         3       Tiruvallur
# 3         4        Cuddalore
# 4         5       Villupuram
# 5         6          Vellore
# 6         7   Tiruvannamalai
# 7         8            Salem
# 8         9         Namakkal
# 9        10       Dharmapuri
# 10       11      Krishnagiri
# 11       12         Tiruppur
# 12       13       Coimbatore
# 13       14            Erode
# 14       15  Tiruchirappalli
# 15       16            Karur
# 16       17       Perambalur
# 17       18      Pudukkottai
# 18       19        Thanjavur
# 19       20        Tiruvarur
# 20       21     Nagapattinam
# 21       22          Madurai
# 22       23            Theni
# 23       24         Dindigul
# 24       25   Ramanathapuram
# 25       26     Virudhunagar
# 26       27        Sivaganga
# 27       28      Tirunelveli
# 28       29      Thoothukudi
# 29       30     The Nilgiris
# 30       31         Ariyalur
# ...

# %%
# create random float numbers between 1 and 100
np.random.uniform(1,100,size=33)
# Out:
# array([83.08873234, 61.38488346, 16.8712835 , 94.13456782, 92.84528094,
#        12.08294337, 84.57346075, 19.19548449, 22.63861536, 39.43185496,
#        23.20188011, 74.0000694 ,  9.36062236, 73.69913269, 28.85889902,
#        64.84190627, 30.21171409,  9.84991413, 10.01671053, 25.08669489,
#        83.56250221, 78.24969263, 58.08911088, 52.35171643, 43.09655084,
#        87.45679807, 58.76047758, 74.62396417, 10.42779624, 89.44298842,
#         3.85779406, 34.32032788, 88.44224465])
