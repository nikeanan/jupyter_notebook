# %%
import pandas as pd

# %%
# read csv file
df = pd.read_csv('soil_geotech_data.csv')

# %%
# show dataframe
df
# Out:
#      Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0          29.96     55.46     24.12     Loamy     Cotton         8
# 1          36.83     69.28     25.17       Red      Wheat        17
# 2          26.95     60.64     35.66       Red     Barley        35
# 3          31.23     44.60     25.08       Red      Maize        17
# 4          33.78     51.39     47.60     Black     Cotton         9
# ..           ...       ...       ...       ...        ...       ...
# 331        35.30     59.61     44.25     Loamy  Oil seeds        10
# 332        39.39     71.67     49.34     Black     Barley        35
# 333        35.79     67.64     45.04       Red     Barley        41
# 334        37.78     73.38     36.03     Black    Tobacco        10
# 335        31.38     48.73     62.27     Loamy    Millets        11
#
#      Potassium  Phosphorous Fertilizer Name
# 0           19           16            Urea
# 1            0           28           28-28
# ...

# %% [markdown]
# # 1. copy()
# 1.1 deep = True

# %%
# deeo=True by deault (Modifications to the data or indices of the copy )
df_copy = df.copy()

# %%
# update valuein original dataframe
df.loc[4,'Moisture'] = 40

# %%
# copy vs original dataframe
df
# Out:
#      Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0          29.96     55.46     24.12     Loamy     Cotton         8
# 1          36.83     69.28     25.17       Red      Wheat        17
# 2          26.95     60.64     35.66       Red     Barley        35
# 3          31.23     44.60     25.08       Red      Maize        17
# 4          33.78     51.39     40.00     Black     Cotton         9
# ..           ...       ...       ...       ...        ...       ...
# 331        35.30     59.61     44.25     Loamy  Oil seeds        10
# 332        39.39     71.67     49.34     Black     Barley        35
# 333        35.79     67.64     45.04       Red     Barley        41
# 334        37.78     73.38     36.03     Black    Tobacco        10
# 335        31.38     48.73     62.27     Loamy    Millets        11
#
#      Potassium  Phosphorous Fertilizer Name
# 0           19           16            Urea
# 1            0           28           28-28
# ...

# %%
df_copy
# Out:
#      Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0          29.96     55.46     24.12     Loamy     Cotton         8
# 1          36.83     69.28     25.17       Red      Wheat        17
# 2          26.95     60.64     35.66       Red     Barley        35
# 3          31.23     44.60     25.08       Red      Maize        17
# 4          33.78     51.39     47.60     Black     Cotton         9
# ..           ...       ...       ...       ...        ...       ...
# 331        35.30     59.61     44.25     Loamy  Oil seeds        10
# 332        39.39     71.67     49.34     Black     Barley        35
# 333        35.79     67.64     45.04       Red     Barley        41
# 334        37.78     73.38     36.03     Black    Tobacco        10
# 335        31.38     48.73     62.27     Loamy    Millets        11
#
#      Potassium  Phosphorous Fertilizer Name
# 0           19           16            Urea
# 1            0           28           28-28
# ...

# %% [markdown]
# # 1.2 deep =False

# %%
# deep=Falges se (Any changes to the data of the original will be reflected in the shallow copy and vice-versa)
df_shallow_copy = df.copy(deep=False)

# %%
# update value in original dataframe
df.loc[4, 'Nitrogen'] = 15

# %%
# shallow copy vs original dataframe
df
# Out:
#      Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0          29.96     55.46     24.12     Loamy     Cotton         8
# 1          36.83     69.28     25.17       Red      Wheat        17
# 2          26.95     60.64     35.66       Red     Barley        35
# 3          31.23     44.60     25.08       Red      Maize        17
# 4          33.78     51.39     40.00     Black     Cotton        15
# ..           ...       ...       ...       ...        ...       ...
# 331        35.30     59.61     44.25     Loamy  Oil seeds        10
# 332        39.39     71.67     49.34     Black     Barley        35
# 333        35.79     67.64     45.04       Red     Barley        41
# 334        37.78     73.38     36.03     Black    Tobacco        10
# 335        31.38     48.73     62.27     Loamy    Millets        11
#
#      Potassium  Phosphorous Fertilizer Name
# 0           19           16            Urea
# 1            0           28           28-28
# ...

# %%
df_shallow_copy
# Out:
#      Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0          29.96     55.46     24.12     Loamy     Cotton         8
# 1          36.83     69.28     25.17       Red      Wheat        17
# 2          26.95     60.64     35.66       Red     Barley        35
# 3          31.23     44.60     25.08       Red      Maize        17
# 4          33.78     51.39     40.00     Black     Cotton        15
# ..           ...       ...       ...       ...        ...       ...
# 331        35.30     59.61     44.25     Loamy  Oil seeds        10
# 332        39.39     71.67     49.34     Black     Barley        35
# 333        35.79     67.64     45.04       Red     Barley        41
# 334        37.78     73.38     36.03     Black    Tobacco        10
# 335        31.38     48.73     62.27     Loamy    Millets        11
#
#      Potassium  Phosphorous Fertilizer Name
# 0           19           16            Urea
# 1            0           28           28-28
# ...

# %% [markdown]
# # 1.3 Simple Assignment

# %%
# make a ssignment
df_new_copy = df

# %%
# update value in original dataframe
df.loc[2,'Temparature'] = 30

# %%
# copy vs original dataframe
df
# Out:
#      Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0          29.96     55.46     24.12     Loamy     Cotton         8
# 1          36.83     69.28     25.17       Red      Wheat        17
# 2          30.00     60.64     35.66       Red     Barley        35
# 3          31.23     44.60     25.08       Red      Maize        17
# 4          33.78     51.39     40.00     Black     Cotton        15
# ..           ...       ...       ...       ...        ...       ...
# 331        35.30     59.61     44.25     Loamy  Oil seeds        10
# 332        39.39     71.67     49.34     Black     Barley        35
# 333        35.79     67.64     45.04       Red     Barley        41
# 334        37.78     73.38     36.03     Black    Tobacco        10
# 335        31.38     48.73     62.27     Loamy    Millets        11
#
#      Potassium  Phosphorous Fertilizer Name
# 0           19           16            Urea
# 1            0           28           28-28
# ...

# %%
df_new_copy
# Out:
#      Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  \
# 0          29.96     55.46     24.12     Loamy     Cotton         8
# 1          36.83     69.28     25.17       Red      Wheat        17
# 2          30.00     60.64     35.66       Red     Barley        35
# 3          31.23     44.60     25.08       Red      Maize        17
# 4          33.78     51.39     40.00     Black     Cotton        15
# ..           ...       ...       ...       ...        ...       ...
# 331        35.30     59.61     44.25     Loamy  Oil seeds        10
# 332        39.39     71.67     49.34     Black     Barley        35
# 333        35.79     67.64     45.04       Red     Barley        41
# 334        37.78     73.38     36.03     Black    Tobacco        10
# 335        31.38     48.73     62.27     Loamy    Millets        11
#
#      Potassium  Phosphorous Fertilizer Name
# 0           19           16            Urea
# 1            0           28           28-28
# ...
