# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('rainfall_by_districts_2019.csv')
df_exams.head()
# Out:
#   S.No      District  \
# 0    1       Chennai
# 1    2  Kancheepuram
# 2    3    Tiruvallur
# 3    4     Cuddalore
# 4    5    Villupuram
#
#    Actual Rainfall in South West Monsoon (June'17 to September'17) in mm  \
# 0                                              449.7
# 1                                              488.5
# 2                                              498.7
# 3                                              465.7
# 4                                              441.3
#
#    Normal Rainfall in South West Monsoon (June'17 to September'17) in mm  \
# 0                                              439.1
# 1                                              490.8
# 2                                              451.6
# 3                                              383.1
# 4                                              408.3
#
#    Actual Rainfall in North East Monsoon (October'17 to December'17) in mm  \
# 0                                              937.8
# ...

# %% [markdown]
# # 1 Selecting one column
# # 1.1 Syntax 1

# %%
# select a column with [] preferred way to select a column
df_exams['District']
# Out:
# 0             Chennai
# 1        Kancheepuram
# 2          Tiruvallur
# 3           Cuddalore
# 4          Villupuram
# 5             Vellore
# 6      Tiruvannamalai
# 7               Salem
# 8            Namakkal
# 9          Dharmapuri
# 10        Krishnagiri
# 11           Tiruppur
# 12         Coimbatore
# 13              Erode
# 14    Tiruchirappalli
# 15              Karur
# 16         Perambalur
# 17        Pudukkottai
# 18          Thanjavur
# 19          Tiruvarur
# 20       Nagapattinam
# 21            Madurai
# 22              Theni
# 23           Dindigul
# 24     Ramanathapuram
# 25       Virudhunagar
# 26          Sivaganga
# 27        Tirunelveli
# 28        Thoothukudi
# 29       The Nilgiris
# 30           Ariyalur
# 31      Kanniyakumari
# 32      State Average
# Name: District, dtype: object

# %%
# check out the data types of a column
type(df_exams['District'])
# Out:
# pandas.core.series.Series

# %%
# series ; attributes and methods
df_exams['District'].index
# Out:
# RangeIndex(start=0, stop=33, step=1)

# %%
# series ; attributes and methods
df_exams['District'].head()
# Out:
# 0         Chennai
# 1    Kancheepuram
# 2      Tiruvallur
# 3       Cuddalore
# 4      Villupuram
# Name: District, dtype: object

# %% [markdown]
# # 1.2 Syntax 2

# %%
# select a column with  .
df_exams.District
# Out:
# 0             Chennai
# 1        Kancheepuram
# 2          Tiruvallur
# 3           Cuddalore
# 4          Villupuram
# 5             Vellore
# 6      Tiruvannamalai
# 7               Salem
# 8            Namakkal
# 9          Dharmapuri
# 10        Krishnagiri
# 11           Tiruppur
# 12         Coimbatore
# 13              Erode
# 14    Tiruchirappalli
# 15              Karur
# 16         Perambalur
# 17        Pudukkottai
# 18          Thanjavur
# 19          Tiruvarur
# 20       Nagapattinam
# 21            Madurai
# 22              Theni
# 23           Dindigul
# 24     Ramanathapuram
# 25       Virudhunagar
# 26          Sivaganga
# 27        Tirunelveli
# 28        Thoothukudi
# 29       The Nilgiris
# 30           Ariyalur
# 31      Kanniyakumari
# 32      State Average
# Name: District, dtype: object

# %%
# select a column with . (pitfalls)
df_exams.Total Actual Rainfall (June'17 to May'18) in mm
# Out:
#   Cell In[16], line 2
#     df_exams.Total Actual Rainfall (June'17 to May'18) in mm
#                    ^
# SyntaxError: invalid syntax

# %%
#  select the same column using []
df_exams["Total Actual Rainfall (June'17 to May'18) in mm"]
# Out:
# 0     1393.5
# 1     1180.0
# 2     1202.4
# 3     1311.0
# 4     1011.7
# 5     1014.0
# 6     1234.1
# 7     1021.2
# 8      845.8
# 9      820.8
# 10    1019.9
# 11     834.6
# 12    1017.2
# 13     769.4
# 14     712.8
# 15     727.3
# 16     962.5
# 17     716.3
# 18     994.5
# 19    1171.7
# 20    1529.8
# 21     875.9
# 22     976.4
# 23     966.4
# 24     583.4
# 25     892.4
# 26    1074.6
# 27    1151.7
# 28     614.0
# 29    1488.6
# 30    1119.1
# 31    1317.4
# 32    1017.2
# Name: Total Actual Rainfall (June'17 to May'18) in mm, dtype: float64

# %%
#  select the same column using []
df_exams['Total Actual Rainfall (June\'17 to May\'18) in mm']
# Out:
# 0     1393.5
# 1     1180.0
# 2     1202.4
# 3     1311.0
# 4     1011.7
# 5     1014.0
# 6     1234.1
# 7     1021.2
# 8      845.8
# 9      820.8
# 10    1019.9
# 11     834.6
# 12    1017.2
# 13     769.4
# 14     712.8
# 15     727.3
# 16     962.5
# 17     716.3
# 18     994.5
# 19    1171.7
# 20    1529.8
# 21     875.9
# 22     976.4
# 23     966.4
# 24     583.4
# 25     892.4
# 26    1074.6
# 27    1151.7
# 28     614.0
# 29    1488.6
# 30    1119.1
# 31    1317.4
# 32    1017.2
# Name: Total Actual Rainfall (June'17 to May'18) in mm, dtype: float64
