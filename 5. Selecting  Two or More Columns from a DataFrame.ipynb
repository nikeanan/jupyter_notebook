# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv('rainfall_by_districts_2019.csv')
df_exams.head()
# Out:
#   S.No      District  \
# 0    1       Chennai
# 1    2  Kancheepuram
# 2    3    Tiruvallur
# 3    4     Cuddalore
# 4    5    Villupuram
#
#    Actual Rainfall in South West Monsoon (June'17 to September'17) in mm  \
# 0                                              449.7
# 1                                              488.5
# 2                                              498.7
# 3                                              465.7
# 4                                              441.3
#
#    Normal Rainfall in South West Monsoon (June'17 to September'17) in mm  \
# 0                                              439.1
# 1                                              490.8
# 2                                              451.6
# 3                                              383.1
# 4                                              408.3
#
#    Actual Rainfall in North East Monsoon (October'17 to December'17) in mm  \
# 0                                              937.8
# ...

# %% [markdown]
# # 1 Selcting two or more columns

# %%
# select 2 columns using [[]]
df_exams[['District',"Actual Rainfall in Winter Season (January'18 to and February'18) in mm"]]
# Out:
#            District  \
# 0           Chennai
# 1      Kancheepuram
# 2        Tiruvallur
# 3         Cuddalore
# 4        Villupuram
# 5           Vellore
# 6    Tiruvannamalai
# 7             Salem
# 8          Namakkal
# 9        Dharmapuri
# 10      Krishnagiri
# 11         Tiruppur
# 12       Coimbatore
# 13            Erode
# 14  Tiruchirappalli
# 15            Karur
# 16       Perambalur
# 17      Pudukkottai
# 18        Thanjavur
# 19        Tiruvarur
# 20     Nagapattinam
# 21          Madurai
# 22            Theni
# 23         Dindigul
# 24   Ramanathapuram
# 25     Virudhunagar
# 26        Sivaganga
# 27      Tirunelveli
# 28      Thoothukudi
# 29     The Nilgiris
# 30         Ariyalur
# 31    Kanniyakumari
# 32    State Average
#
#     Actual Rainfall in Winter Season (January'18 to and February'18) in mm
# 0                                                 3.1
# 1                                                 4.4
# 2                                                 8.1
# ...

# %%
# check out the datatype of the selection
type(df_exams[['District',"Actual Rainfall in Winter Season (January'18 to and February'18) in mm"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# select 2 or more columns using [[]]
df_exams[['District',"Total Normal Rainfall (June'17 to May'18) in mm","Total Actual Rainfall (June'17 to May'18) in mm","Actual Rainfall in Winter Season (January'18 to and February'18) in mm"]]
# Out:
#            District  Total Normal Rainfall (June'17 to May'18) in mm  \
# 0           Chennai                                           1324.2
# 1      Kancheepuram                                           1227.7
# 2        Tiruvallur                                           1139.6
# 3         Cuddalore                                           1206.7
# 4        Villupuram                                           1011.6
# 5           Vellore                                            936.2
# 6    Tiruvannamalai                                           1040.0
# 7             Salem                                            997.9
# 8          Namakkal                                            793.4
# 9        Dharmapuri                                            902.1
# 10      Krishnagiri                                            850.7
# 11         Tiruppur                                            618.2
# 12       Coimbatore                                            689.3
# ...

# %%
# we can't select 2 or more columns with th ","
df_exams.'District',"Actual Rainfall in Winter Season (January'18 to and February'18) in mm"
# Out:
#   Cell In[9], line 2
#     df_exams.'District',"Actual Rainfall in Winter Season (January'18 to and February'18) in mm"
#              ^
# SyntaxError: invalid syntax
